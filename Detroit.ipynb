# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_context('paper',font_scale=1.5)

# %%
plt.figure(figsize=(5,5))
p = np.random.uniform(0,50,50)
y = np.random.uniform(-5,-15,50)

plt.scatter(p,y,marker='d',s=100)
plt.fill_between(np.arange(30),np.repeat(-30,30),-np.arange(30),color='grey',
                 alpha=.5)
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k',)

plt.ylabel('Trump vote %\n - registered republicans %')
plt.xlabel('Registered republicans %')
ax = plt.gca()
ax.yaxis.grid(True)
plt.tight_layout()
plt.savefig('ThisIsImpossible.png')

# %%
def vote(p,n,p_biden_given_r,p_trump_given_r):
    total_votes = 0
    for idx in range(n):
        if np.random.uniform() < p:
            if np.random.uniform() < p_biden_given_r:
                pass
            else:
                total_votes +=1
        else:
            if np.random.uniform() < p_trump_given_d:
                total_votes+=1
    return total_votes / n

k = 100
n = np.random.poisson(500,k)
print(n)

p_biden_given_r = .4
p_trump_given_d = .07

p_nominal = np.linspace(0.001,.5, k)

#Uncomment this if you want registered_r with uncertainty
#phi = 25
p_actual = p_nominal #np.random.beta(p_nominal*phi, (1-p_nominal)*phi)


#plot
plt.figure(figsize=(5,5))
votes = [vote(item,n[idx],
              p_biden_given_r,
              p_trump_given_d) for idx, item in enumerate(p_actual)]-p_nominal


plt.scatter(p_nominal*100, votes*100,
            marker='d',s=100)
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylabel('Trump vote %\n - registered republicans %')
plt.xlabel('Registered republicans %')
ax = plt.gca()
ax.yaxis.grid(True)
plt.xticks([0,10,20,30,40,50])
plt.tight_layout()

plt.savefig('ThisIsReasonable.png')
# Out:
# [476 545 467 517 488 483 469 497 514 476 466 492 499 532 519 469 543 528
#  518 526 543 480 485 518 513 511 493 477 483 465 508 504 487 512 481 486
#  495 486 512 523 516 497 519 419 498 521 515 519 547 522 533 549 496 501
#  501 456 454 479 512 488 516 473 450 482 523 496 471 450 493 543 478 468
#  520 508 521 493 492 507 505 482 511 515 493 499 483 491 499 551 492 480
#  500 451 528 512 504 510 521 479 516 477]

# %%
def vote(p,n,p_biden_given_r,p_trump_given_r):
    total_votes = 0
    for idx in range(n):
        if np.random.uniform() < p:
            if np.random.uniform() < p_biden_given_r:
                pass
            else:
                total_votes +=1
        else:
            if np.random.uniform() < p_trump_given_d:
                total_votes+=1
    return total_votes / n

k = 100
n = np.random.poisson(500,k)
print(n)

p_biden_given_r = .4
p_trump_given_d = .07

p_nominal = np.linspace(0.01,.5, k)

#Uncomment this if you want registered_r with uncertainty
#phi = 25
p_actual = p_nominal #np.random.beta(p_nominal*phi, (1-p_nominal)*phi)


#plot
plt.figure(figsize=(5,5))
votes = [vote(item,n[idx],
              p_biden_given_r,
              p_trump_given_d) for idx, item in enumerate(p_actual)]/p_nominal


plt.scatter(p_nominal*100, votes*100,
            marker='d',s=100)

plt.plot([0,50],[0,0], ls='--',color='k')
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylabel('Trump vote %\n / registered republicans %')
plt.xlabel('Registered republicans %')
ax = plt.gca()
ax.yaxis.grid(True)
plt.xticks([0,10,20,30,40,50])
plt.tight_layout()

plt.savefig('ThisIsReasonable.png')
# Out:
# [494 491 483 507 506 474 510 538 510 524 451 530 486 488 525 481 522 500
#  525 519 504 513 501 498 535 537 496 522 494 517 513 478 498 509 544 513
#  487 497 489 466 439 539 505 485 529 509 468 458 538 482 526 437 496 477
#  462 497 508 465 518 501 496 510 534 509 544 490 507 508 551 469 495 474
#  487 498 496 534 494 460 510 488 523 493 515 482 510 492 465 487 489 458
#  449 541 472 522 500 500 455 557 530 497]

# %%
plt.figure(figsize=(5,5))
p = np.random.uniform(0,50,50)
y = np.random.uniform(-5,-15,50)

plt.fill_between(np.arange(100),np.repeat(-100,100),-np.arange(100),color='black',
                 alpha=.5)

plt.fill_between(np.arange(100),np.repeat(100,100),100-np.arange(100),color='black',
                 alpha=.5)

plt.ylim(-100,100)
plt.xlim(0,100)
plt.plot([0,100],[0,0], ls='--',color='k',)

plt.ylabel('Trump vote %\n - registered republicans %')
plt.xlabel('Registered republicans %')
ax = plt.gca()
ax.yaxis.grid(True)
plt.tight_layout()
plt.savefig('PossibleLocations.png')

# %%
def vote(p,n,p_biden_given_r,p_trump_given_r):
    total_votes = 0
    for idx in range(n):
        if np.random.uniform() < p:
            if np.random.uniform() < p_biden_given_r:
                pass
            else:
                total_votes +=1
        else:
            if np.random.uniform() < p_trump_given_d:
                total_votes+=1
    return total_votes / n

k = 100
n = np.random.poisson(500,k)
print(n)

p_biden_given_r = .4
p_trump_given_d = .07

p_nominal = np.linspace(0.001,.5, k)

#Uncomment this if you want registered_r with uncertainty
#phi = 25
p_actual = p_nominal #np.random.beta(p_nominal*phi, (1-p_nominal)*phi)


#plot
plt.figure(figsize=(5,5))
votes = [vote(np.random.uniform(0-item, 1-item),n[idx],
              p_biden_given_r,
              p_trump_given_d) for idx, item in enumerate(p_actual)]-p_nominal


plt.scatter(p_nominal*100, votes*100,
            marker='d',s=100)
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylabel('Trump vote %\n - registered republicans %')
plt.xlabel('Registered republicans %')
ax = plt.gca()
ax.yaxis.grid(True)
plt.xticks([0,10,20,30,40,50])
plt.tight_layout()

plt.savefig('ThisIsRandom.png')
# Out:
# [554 479 524 498 479 494 481 543 509 487 513 514 478 505 523 517 504 510
#  536 469 483 479 473 466 451 496 512 482 488 552 500 497 519 553 502 483
#  490 525 533 497 485 508 473 496 513 503 481 490 500 485 506 529 510 474
#  489 489 484 492 484 526 506 479 473 513 473 501 519 522 480 510 551 488
#  480 523 522 537 527 481 516 478 487 470 524 502 495 521 491 483 520 505
#  507 489 480 494 545 493 528 458 487 497]

# %%
def vote(p,n,p_biden_given_r,p_trump_given_r):
    total_votes = 0
    for idx in range(n):
        if np.random.uniform() < p:
            if np.random.uniform() < p_biden_given_r:
                pass
            else:
                total_votes +=1
        else:
            if np.random.uniform() < p_trump_given_d:
                total_votes+=1
    return total_votes / n

k = 100
n = np.random.poisson(500,k)
print(n)

p_biden_given_r = .4
p_trump_given_d = .07

p_nominal = np.linspace(0.001,.5, k)

#Uncomment this if you want registered_r with uncertainty
#phi = 25
p_actual = p_nominal #np.random.beta(p_nominal*phi, (1-p_nominal)*phi)


#plot
plt.figure(figsize=(5,5))
votes = [vote(np.random.uniform(0-item, .20*item-item),n[idx],
              p_biden_given_r,
              p_trump_given_d) for idx, item in enumerate(p_actual)]-p_nominal


plt.scatter(p_nominal*100, votes*100,
            marker='d',s=100)
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylim(-30,30)
plt.xlim(0,50)
plt.plot([0,50],[0,0], ls='--',color='k')
plt.ylabel('Trump vote %\n - registered republicans %')
plt.xlabel('Registered republicans %')
ax = plt.gca()
ax.yaxis.grid(True)
plt.xticks([0,10,20,30,40,50])
plt.tight_layout()

plt.savefig('ThisIsRandom.png')
# Out:
# [525 486 485 519 530 504 488 514 562 483 521 544 486 479 493 500 466 458
#  493 495 501 507 547 504 480 500 478 488 484 483 529 554 519 518 512 490
#  525 519 512 514 501 501 489 468 522 471 485 499 530 460 446 497 535 494
#  484 521 554 513 499 507 503 531 510 513 481 481 499 511 492 501 502 487
#  495 490 560 503 505 501 514 457 506 509 480 506 529 479 474 513 513 521
#  498 477 495 515 438 507 505 543 509 489]
